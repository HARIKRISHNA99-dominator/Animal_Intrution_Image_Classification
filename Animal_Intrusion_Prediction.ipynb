# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models

# %%
from tensorflow.python.keras.saving.save import load_model
model=load_model("/content/drive/MyDrive/Animal_Intrusion_Saved_Model/anim_model.h5")

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
training=ImageDataGenerator(rescale=1/255).flow_from_directory("/content/drive/MyDrive/Animal_Intrution/",target_size=(244,244),batch_size=16,class_mode='sparse')
# Out:
# Found 5935 images belonging to 3 classes.

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
X=image.load_img("/content/drive/MyDrive/Animal_Test/elephant.jpg",target_size=(244,244))
plt.imshow(X)
plt.show()
X=image.img_to_array(X)
X=np.expand_dims(X,axis=0)
X=np.vstack([X])
print(model.predict(X))
f=model.predict(X)
max=f[0][0]
index=0
for i in range(0,len(f[0])):
  if f[0][i]>max:
    max=f[0][i]
    index=i
d=["Horse","Elephant","Cow"]
print(d[index])
# Out:
# [[2.05847360e-02 9.79415119e-01 1.06932774e-07]]
# Elephant
